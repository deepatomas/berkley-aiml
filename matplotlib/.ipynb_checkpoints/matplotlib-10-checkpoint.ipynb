# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
from matplotlib import datetime as mpl_plots
from collections import Counter

# %%
###time series graph

plt.style.use('seaborn-v0_8')
ds = pd.read_csv("data8.csv")
ds.info()

price_date = pd.to_datetime(ds["Date"]).sort_values()
price_close = ds["Close"]
plt.plot_date(price_date, price_close,linestyle="solid")
plt.gcf().autofmt_xdate()
plt.legend(loc="upper left")
plt.title("Bitcoin prices")
plt.xlabel("Dates")
plt.ylabel("Closing Price")
plt.tight_layout()
plt.savefig("matplot-graph-8.png")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14 non-null     object
#  1   Open       14 non-null     float64
#  2   High       14 non-null     float64
#  3   Low        14 non-null     float64
#  4   Close      14 non-null     float64
#  5   Adj Close  14 non-null     float64
#  6   Volume     14 non-null     int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 916.0+ bytes
